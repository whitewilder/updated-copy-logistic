# %%
import os
import pandas as pd

# %%
path='C:/Users/hp/Downloads/scorecardpy-master/'
os.chdir(path)

# %%
os.getcwd()

# %%
import scorecardpy as sc

# %%
df= pd.read_csv('scorecardpy/data/germancredit.csv')

# %%
# data prepare ------
# load germancredit data
dat = sc.germancredit()

# %%
# filter variable via missing rate, iv, identical value rate
dt_s = sc.var_filter(dat, y="creditability")
# Out:
# [INFO] filtering variables ...
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\condition_fun.py:141: UserWarning: The positive value in "creditability" was replaced by 1 and negative value by 0.
#   warnings.warn("The positive value in \"{}\" was replaced by 1 and negative value by 0.".format(y))

# %%
# breaking dt into train and test
train, test = sc.split_df(dt_s, 'creditability').values()

# %%
# woe binning ------
bins = sc.woebin(dt_s, y="creditability")
# sc.woebin_plot(bins)
# Out:
# [INFO] creating woe binning ...

# %%
# Find important variable
sc.woebin_plot(bins)
# Out:
# {'other_installment_plans': <Figure size 640x480 with 2 Axes>,
#  'present_employment_since': <Figure size 640x480 with 2 Axes>,
#  'status_of_existing_checking_account': <Figure size 640x480 with 2 Axes>,
#  'savings_account_and_bonds': <Figure size 640x480 with 2 Axes>,
#  'purpose': <Figure size 640x480 with 2 Axes>,
#  'other_debtors_or_guarantors': <Figure size 640x480 with 2 Axes>,
#  'credit_amount': <Figure size 640x480 with 2 Axes>,
#  'property': <Figure size 640x480 with 2 Axes>,
#  'credit_history': <Figure size 640x480 with 2 Axes>,
#  'housing': <Figure size 640x480 with 2 Axes>,
#  'installment_rate_in_percentage_of_disposable_income': <Figure size 640x480 with 2 Axes>,
#  'duration_in_month': <Figure size 640x480 with 2 Axes>,
#  'age_in_years': <Figure size 640x480 with 2 Axes>}

# %%
breaks_adj = {
    'age.in.years': [26, 35, 40],
    'other.debtors.or.guarantors': ["none", "co-applicant%,%guarantor"]
}
bins_adj = sc.woebin(dt_s, y="creditability", breaks_list=breaks_adj)
# Out:
# [INFO] creating woe binning ...

# %%
# converting train and test into woe values
train_woe = sc.woebin_ply(train, bins_adj)
test_woe = sc.woebin_ply(test, bins_adj)

y_train = train_woe.loc[:,'creditability']
X_train = train_woe.loc[:,train_woe.columns != 'creditability']
y_test = test_woe.loc[:,'creditability']
X_test = test_woe.loc[:,train_woe.columns != 'creditability']
# Out:
# [INFO] converting into woe values ...
# [INFO] converting into woe values ...

# %%
# binning adjustment
# # adjust breaks interactively
# breaks_adj = sc.woebin_adj(dt_s, "creditability", bins) 
# # or specify breaks manually


# logistic regression ------
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(penalty='l1', C=0.9, solver='saga', n_jobs=-1)
lr.fit(X_train, y_train)
# lr.coef_
# lr.intercept_

# predicted proability
train_pred = lr.predict_proba(X_train)[:,1]
test_pred = lr.predict_proba(X_test)[:,1]

# %%
# performance ks & roc ------
train_perf = sc.perf_eva(y_train, train_pred, title = "train")
test_perf = sc.perf_eva(y_test, test_pred, title = "test")

# score ------
card = sc.scorecard(bins_adj, lr, X_train.columns)
# credit score
train_score = sc.scorecard_ply(train, card, print_step=0)
test_score = sc.scorecard_ply(test, card, print_step=0)

# psi
sc.perf_psi(
  score = {'train':train_score, 'test':test_score},
  label = {'train':y_train, 'test':y_test}
)
# Out:
# {'psi':   variable       PSI
#  0    score  0.010375,
#  'pic': {'score': <Figure size 640x480 with 2 Axes>}}

# %%
# scorecard
card = sc.scorecard(bins, lr, X_train.columns)

train_score = sc.scorecard_ply(train, card, only_total_score=False, print_step=0, replace_blank_na=True, var_kp = None)
test_score = sc.scorecard_ply(test, card, only_total_score=False, print_step=0, replace_blank_na=True, var_kp = None)
score = sc.scorecard_ply(dat, card, only_total_score=False, print_step=0, replace_blank_na=True, var_kp = None)

# %%
score
# Out:
#      duration_in_month_points  housing_points  \
# 0                        52.0             7.0
# 1                       -45.0             7.0
# 2                        14.0             7.0
# 3                       -21.0           -17.0
# 4                        -4.0           -17.0
# ..                        ...             ...
# 995                      14.0             7.0
# 996                      -4.0             7.0
# 997                      14.0             7.0
# 998                     -45.0           -17.0
# 999                     -45.0             7.0
#
#      status_of_existing_checking_account_points  \
# 0                                         -34.0
# 1                                         -34.0
# 2                                          66.0
# 3                                         -34.0
# 4                                         -34.0
# ..                                          ...
# 995                                        66.0
# 996                                       -34.0
# 997                                        66.0
# 998                                       -34.0
# 999                                       -34.0
#
#      other_debtors_or_guarantors_points  other_installment_plans_points  \
# 0                                  -2.0                             6.0
# 1                                  -2.0                             6.0
# 2                                  -2.0                             6.0
# 3                                  33.0                             6.0
# 4                                  -2.0                             6.0
# ..                                  ...                             ...
# 995                                -2.0                             6.0
# 996                                -2.0                             6.0
# 997                                -2.0                             6.0
# 998                                -2.0                             6.0
# 999                                -2.0                             6.0
#
#      credit_history_points  savings_account_and_bonds_points  property_points  \
# 0                     30.0                              31.0              5.0
# 1                     -4.0                             -11.0              5.0
# 2                     30.0                             -11.0              5.0
# 3                     -4.0                             -11.0             -0.0
# 4                     -4.0                             -11.0             -7.0
# ..                     ...                               ...              ...
# 995                   -4.0                             -11.0              5.0
# 996                   -4.0                             -11.0             -0.0
# 997                   -4.0                             -11.0             -0.0
# 998                   -4.0                             -11.0             -7.0
# 999                   30.0                              -6.0             -0.0
#
#      purpose_points  present_employment_since_points  \
# 0              30.0                              5.0
# 1              30.0                             -1.0
# 2             -20.0                              8.0
# 3             -20.0                              8.0
# 4             -20.0                             -1.0
# ..              ...                              ...
# 995           -20.0                              8.0
# 996            59.0                             -1.0
# 997            30.0                              5.0
# 998            30.0                             -1.0
# 999            59.0                             -9.0
#
#      installment_rate_in_percentage_of_disposable_income_points  \
# 0                                                -20.0
# 1                                                 24.0
# 2                                                 24.0
# 3                                                 24.0
# 4                                                  8.0
# ..                                                 ...
# 995                                                8.0
# 996                                              -20.0
# 997                                              -20.0
# 998                                              -20.0
# 999                                                8.0
#
#      age_in_years_points  credit_amount_points  score
# 0                   13.0                  -2.0  568.0
# 1                  -32.0                 -23.0  367.0
# 2                   13.0                  15.0  602.0
# 3                   13.0                 -23.0  401.0
# 4                   13.0                 -23.0  351.0
# ..                   ...                   ...    ...
# 995                 -8.0                  43.0  559.0
# 996                 13.0                  15.0  471.0
# 997                 13.0                  -2.0  549.0
# 998                -32.0                  15.0  325.0
# 999                 10.0                 -23.0  448.0
#
# [1000 rows x 14 columns]

# %%
sc.perf_psi(
  score = {'train':train_score, 'test':test_score},
  label = {'train':y_train, 'test':y_test}
)
# Out:
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:504: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = dat[sn]
# C:\Users\hp\Downloads\scorecardpy-master\scorecardpy\perf.py:502: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.loc[:,'bin'] = pd.cut(dat[sn], brkp, right=False, labels=labels)
# {'psi':                                              variable       PSI
#  0                            duration_in_month_points  0.021212
#  1                                      housing_points  0.001679
#  2          status_of_existing_checking_account_points  0.003004
#  3                  other_debtors_or_guarantors_points  0.002553
#  4                      other_installment_plans_points  0.005630
#  5                               credit_history_points  0.004222
#  6                    savings_account_and_bonds_points  0.005146
#  7                                     property_points  0.007860
#  8                                      purpose_points  0.019215
#  9                     present_employment_since_points  0.005231
#  10  installment_rate_in_percentage_of_disposable_i...  0.002579
#  11                                age_in_years_points  0.007580
#  12                               credit_amount_points  0.006217
#  13                                              score  0.010375,
#  'pic': {'duration_in_month_points': <Figure size 640x480 with 2 Axes>,
#   'housing_points': <Figure size 640x480 with 2 Axes>,
#   'status_of_existing_checking_account_points': <Figure size 640x480 with 2 Axes>,
#   'other_debtors_or_guarantors_points': <Figure size 640x480 with 2 Axes>,
#   'other_installment_plans_points': <Figure size 640x480 with 2 Axes>,
#   'credit_history_points': <Figure size 640x480 with 2 Axes>,
#   'savings_account_and_bonds_points': <Figure size 640x480 with 2 Axes>,
#   'property_points': <Figure size 640x480 with 2 Axes>,
#   'purpose_points': <Figure size 640x480 with 2 Axes>,
#   'present_employment_since_points': <Figure size 640x480 with 2 Axes>,
#   'installment_rate_in_percentage_of_disposable_income_points': <Figure size 640x480 with 2 Axes>,
#   'age_in_years_points': <Figure size 640x480 with 2 Axes>,
#   'credit_amount_points': <Figure size 640x480 with 2 Axes>,
#   'score': <Figure size 640x480 with 2 Axes>}}
